# %% [markdown]
# # BATTLE OF THE NEIGHBORHOODS

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# ### First, let us import the relevant libraries

# %%
import numpy as np
import pandas as pd

#!conda install -c conda-forge folium
import folium

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

import matplotlib.pyplot as plt

import requests
import json

from pandas.io.json import json_normalize
from sklearn.cluster import KMeans

# %% [markdown]
# ### We will retrieve the coordinates for Connaught Place

# %%
address = 'Connaught Place, National Capital Territory of Delhi'
geolocator = Nominatim(user_agent = 'New')
location = geolocator.geocode(address)
longitude = location.longitude
latitude = location.latitude

# %% [markdown]
# ### Let's see the location on a map

# %%
map_delhi = folium.Map(location = [latitude, longitude], zoom_start = 12)
label = folium.Popup('Connaught Place')
folium.CircleMarker(
    [latitude, longitude],
    radius = 5,
    popup = label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7).add_to(map_delhi)

# %%
map_delhi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We will set up the credentials

# %%
# The code was removed by Watson Studio for sharing.

# %%
LIMIT = 100
radius = 3000

# %% [markdown]
# ## For Restaurants

# %% [markdown]
# #### We will query all the restaurants in Connaught Place

# %%
query = 'Restaurant'
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,
    query,
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb2e9a5b1cac0001ca3bc92'},
#  'response': {'venues': [{'id': '5177f8d5e4b0f361220d4766',
#     'name': 'Anand Restaurant',
#     'location': {'address': '35 Community Centre',
#      'crossStreet': 'New Friends Colony',
#      'lat': 28.632091466562407,
#      'lng': 77.22495786591341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.632091466562407,
#        'lng': 77.22495786591341}],
#      'distance': 510,
#      'postalCode': '110025',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['35 Community Centre (New Friends Colony)',
#       'New Delhi 110025',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5b991352f00a70002cdff3a6',
#     'name': 'FUJI RESTAURANT & BAR',
#     'location': {'lat': 28.631444,
#      'lng': 77.219244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.631444,
#        'lng': 77.219244}],
#      'distance': 54,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['New Delhi 110001', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5467166a498e6c2b038ef3bc',
#     'name': 'The Host Restaurant',
#     'location': {'lat': 28.631860686377472,
#      'lng': 77.22037136182287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.631860686377472,
#        'lng': 77.22037136182287}],
#      'distance': 77,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4f5063bbe4b062d9d9d5a175',
#     'name': 'Tom Yam Rooftop Restaurant',
#     'location': {'address': 'Hare Krishna hotel',
#      'lat': 28.641011,
#      'lng': 77.212043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641011,
#        'lng': 77.212043}],
#      'distance': 1312,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Hare Krishna hotel',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '54086753498e0efae46a1c8f',
#     'name': 'anand restaurant cp',
#     'location': {'lat': 28.6315733133297,
#      'lng': 77.22062398908098,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.6315733133297,
#        'lng': 77.22062398908098}],
#      'distance': 83,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '542fc95c498e839d725fd0a4',
#     'name': "York's Restaurant",
#     'location': {'address': 'M Block',
#      'crossStreet': 'CP',
#      'lat': 28.632262,
#      'lng': 77.219214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.632262,
#        'lng': 77.219214}],
#      'distance': 113,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['M Block (CP)', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5234712f11d2133b3433fb36',
#     'name': 'KFC Restaurant',
#     'location': {'address': 'A Block, Inner Circle',
#      'crossStreet': 'Connaught Place',
#      'lat': 28.633158317050075,
#      'lng': 77.21820120068533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.633158317050075,
#        'lng': 77.21820120068533}],
#      'distance': 251,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['A Block, Inner Circle (Connaught Place)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5023f368e4b00ac2d887e3be',
#     'name': 'Zafron restaurant',
#     'location': {'lat': 28.633371353149414,
#      'lng': 77.22038269042969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.633371353149414,
#        'lng': 77.22038269042969}],
#      'distance': 228,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4b80e20df964a5205c9030e3',
#     'name': 'Zen Restaurant',
#     'location': {'address': 'B 25 Connaught Place',
#      'lat': 28.63405245242278,
#      'lng': 77.21931859967171,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63405245242278,
#        'lng': 77.21931859967171}],
#      'distance': 300,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['B 25 Connaught Place',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4fae2e04e4b0771d82721cab',
#     'name': 'My Bar Lounge & Restaurant',
#     'location': {'address': 'G 68, Outer Circle, Connaught Place',
#      'crossStreet': 'Opposite Alka Hotel',
#      'lat': 28.632387528689907,
#      'lng': 77.21671670393215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.632387528689907,
#        'lng': 77.21671670393215}],
#      'distance': 320,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['G 68, Outer Circle, Connaught Place (Opposite Alka Hotel)',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4b79606ef964a52089f62ee3',
#     'name': 'Kwality Restaurant',
#     'location': {'address': 'Connaught Place',
#      'lat': 28.629743645035568,
#      'lng': 77.21743130219578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.629743645035568,
#        'lng': 77.21743130219578}],
#      'distance': 294,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Connaught Place', 'New Delhi', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '547b43fa498eaea3bee44d97',
#     'name': 'Japanese Fuji Restaurant',
#     'location': {'address': 'Speedbird house, M Block, Middle circle, Connaught Place',
#      'lat': 28.63309875268639,
#      'lng': 77.2221218013156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63309875268639,
#        'lng': 77.2221218013156}],
#      'distance': 297,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Speedbird house, M Block, Middle circle, Connaught Place',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '525ad0c511d2bc4d09aca87d',
#     'name': 'Anand Restaurant',
#     'location': {'lat': 28.628908157348633,
#      'lng': 77.22090148925781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.628908157348633,
#        'lng': 77.22090148925781}],
#      'distance': 296,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '51e7c557498e3b78d5fe9fda',
#     'name': 'White water restaurant',
#     'location': {'address': 'Opposite odeon cinema',
#      'lat': 28.634356016589646,
#      'lng': 77.22068574232857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.634356016589646,
#        'lng': 77.22068574232857}],
#      'distance': 342,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Opposite odeon cinema', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '547af384498e385d54083108',
#     'name': 'Vega Pure Vegetarian Restaurant',
#     'location': {'lat': 28.632273,
#      'lng': 77.216532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.632273,
#        'lng': 77.216532}],
#      'distance': 333,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4d4d658b13d88cfa9b7a08da',
#     'name': 'Parikrama - The Revolving Restaurant',
#     'location': {'address': '22, Antariksh Bhavan, Kasturba Gandhi Marg, Connaught Place',
#      'lat': 28.62877338737562,
#      'lng': 77.22294850059579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.62877338737562,
#        'lng': 77.22294850059579}],
#      'distance': 423,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['22, Antariksh Bhavan, Kasturba Gandhi Marg, Connaught Place',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5a97f8f2123a193595a48e66',
#     'name': 'Ravayat Restaurant',
#     'location': {'lat': 28.634632,
#      'lng': 77.218534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.634632,
#        'lng': 77.218534}],
#      'distance': 382,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['New Delhi 110001', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '52ac467f11d2ea1238661c31',
#     'name': 'My Lounge Bar & Restaurant',
#     'location': {'address': 'G-68,Outer Circle, Connaught Place, New Delhi',
#      'crossStreet': 'connaught place',
#      'lat': 28.63105176179807,
#      'lng': 77.21624314785002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63105176179807,
#        'lng': 77.21624314785002}],
#      'distance': 348,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['G-68,Outer Circle, Connaught Place, New Delhi (connaught place)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4b7421c5f964a5204ac92de3',
#     'name': 'Veda Restaurant',
#     'location': {'address': 'H 27',
#      'crossStreet': 'Connaught Place',
#      'lat': 28.635210214696645,
#      'lng': 77.21807926655758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.635210214696645,
#        'lng': 77.21807926655758}],
#      'distance': 457,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['H 27 (Connaught Place)',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '50437091e4b0f3004270711d',
#     'name': 'zaffron Restaurant',
#     'location': {'lat': 28.63380912514697,
#      'lng': 77.21671662707087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63380912514697,
#        'lng': 77.21671662707087}],
#      'distance': 404,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4f68975ee4b0551e6c8651a8',
#     'name': 'Maharani Restaurant',
#     'location': {'address': 'Outer Circle',
#      'crossStreet': 'Connaught Place',
#      'lat': 28.63538748649201,
#      'lng': 77.21987171965529,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63538748649201,
#        'lng': 77.21987171965529}],
#      'distance': 445,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Outer Circle (Connaught Place)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d120941735',
#       'name': 'Karaoke Bar',
#       'pluralName': 'Karaoke Bars',
#       'shortName': 'Karaoke',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4c30890aac0ab71332021c1e',
#     'name': 'Gulati Restaurant',
#     'location': {'address': 'Pandara Road',
#      'lat': 28.608010137218567,
#      'lng': 77.22998865890446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.608010137218567,
#        'lng': 77.22998865890446}],
#      'distance': 2786,
#      'postalCode': 'India',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Pandara Road',
#       'New Delhi India',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '52f74a49498e2e8f0c83a5fb',
#     'name': 'Pioneer - The Chinese Restaurant',
#     'location': {'lat': 28.634521484375,
#      'lng': 77.21696472167969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.634521484375,
#        'lng': 77.21696472167969}],
#      'distance': 445,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '51e194e8498e0251c833a8ba',
#     'name': 'Royal Restaurant',
#     'location': {'address': 'Connaught place',
#      'lat': 28.63549919409385,
#      'lng': 77.21471236971578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.63549919409385,
#        'lng': 77.21471236971578}],
#      'distance': 675,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Connaught place', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '513cb2abe4b0178148bac8c1',
#     'name': 'Loknath Restaurant',
#     'location': {'lat': 28.635308006405356,
#      'lng': 77.21531870325646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.635308006405356,
#        'lng': 77.21531870325646}],
#      'distance': 618,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4edb83a60e61d46ad9567ee4',
#     'name': 'Janta Restaurant',
#     'location': {'lat': 28.635308006405356,
#      'lng': 77.22495786591341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.635308006405356,
#        'lng': 77.22495786591341}],
#      'distance': 667,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5c3df5613149b9002ce82722',
#     'name': 'Oko Pan-Asian Restaurant Lalit Hotel',
#     'location': {'lat': 28.631703,
#      'lng': 77.22723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.631703,
#        'lng': 77.22723}],
#      'distance': 727,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['New Delhi 110001', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4cbb2592dd41a35df95eeca0',
#     'name': 'Rajdhani Thali',
#     'location': {'address': 'Shop No. 9A, Atmaram Mansion, Scindia House, Connaught Circus, Connaught Place',
#      'crossStreet': 'Connaught Place',
#      'lat': 28.62999946326596,
#      'lng': 77.2204011327264,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.62999946326596,
#        'lng': 77.2204011327264}],
#      'distance': 165,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Shop No. 9A, Atmaram Mansion, Scindia House, Connaught Circus, Connaught Place (Connaught Place)',
#       'New Delhi 110001',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '56e558e1498e87269b942835',
#     'name': 'Bangla Sweet & Spice restaurant',
#     'location': {'lat': 28.633858,
#      'lng': 77.20947,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.633858,
#        'lng': 77.20947}],
#      'distance': 1045,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dff5',
#       'name': 'Bengali Restaurant',
#       'pluralName': 'Bengali Restaurants',
#       'shortName': 'Bengali',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4f1ed1a4e4b07fde7eebe662',
#     'name': 'Jasmine Restaurant @ The Royal Plaza',
#     'location': {'address': 'The Royal Plaza Hotel',
#      'lat': 28.62059425954847,
#      'lng': 77.21769909375585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.62059425954847,
#        'lng': 77.21769909375585}],
#      'distance': 1218,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['The Royal Plaza Hotel',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5051fafde4b0b5f7e76af1a6',
#     'name': 'Metropolis Restaurant',
#     'location': {'address': '1634 Main Bazaar | Paharganjj',
#      'lat': 28.640752509715924,
#      'lng': 77.21054093526213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.640752509715924,
#        'lng': 77.21054093526213}],
#      'distance': 1380,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['1634 Main Bazaar | Paharganjj',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5adb69991b0ea56cac967b83',
#     'name': 'Novele Restaurant, Shangri La New Delhi',
#     'location': {'lat': 28.621067,
#      'lng': 77.217321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.621067,
#        'lng': 77.217321}],
#      'distance': 1173,
#      'postalCode': '110001',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['New Delhi 110001', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4dbcf5c30cb691071cb0815a',
#     'name': 'New Mount Everest Restaurant',
#     'location': {'lat': 28.641167907128445,
#      'lng': 77.21346039340064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641167907128445,
#        'lng': 77.21346039340064}],
#      'distance': 1252,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['New Delhi', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '52ce86c1498ed4eed58394a9',
#     'name': 'The exotic roof top Restaurant',
#     'location': {'lat': 28.641039172929673,
#      'lng': 77.2136341282525,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641039172929673,
#        'lng': 77.2136341282525}],
#      'distance': 1231,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '52adae9a498ea34d84bc06bc',
#     'name': 'kamal restaurant',
#     'location': {'address': '3966/67, Kaseru Walan, Pahar Ganj',
#      'lat': 28.64087677001953,
#      'lng': 77.21484375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.64087677001953,
#        'lng': 77.21484375}],
#      'distance': 1162,
#      'postalCode': '110055',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['3966/67, Kaseru Walan, Pahar Ganj',
#       'New Delhi 110055',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5e3e5a4b22426c000883aac6',
#     'name': 'Singh’s Cafe & Restaurant',
#     'location': {'address': '1176, Main Bazar, Six Toori Chowk',
#      'lat': 28.641117,
#      'lng': 77.213342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641117,
#        'lng': 77.213342}],
#      'distance': 1253,
#      'postalCode': '110055',
#      'cc': 'IN',
#      'city': 'Нью-Дели',
#      'state': 'Дели',
#      'country': 'India',
#      'formattedAddress': ['1176, Main Bazar, Six Toori Chowk',
#       'Нью-Дели 110055',
#       'Дели',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5bcde5179ba3e50039efed10',
#     'name': "Leo's Restaurant",
#     'location': {'lat': 28.64038,
#      'lng': 77.210266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.64038,
#        'lng': 77.210266}],
#      'distance': 1367,
#      'postalCode': '110055',
#      'cc': 'IN',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['110055', 'Delhi', 'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfdd',
#       'name': 'North Indian Restaurant',
#       'pluralName': 'North Indian Restaurants',
#       'shortName': 'North Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4e2fd531ae60231c0330b531',
#     'name': 'Malahotra Restaurant',
#     'location': {'lat': 28.641051838211972,
#      'lng': 77.21033320184107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641051838211972,
#        'lng': 77.21033320184107}],
#      'distance': 1418,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Pahar Ganj',
#      'country': 'India',
#      'formattedAddress': ['New Delhi', 'Pahar Ganj', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '56d449f5cd1053f885f27f7b',
#     'name': 'My Love Restaurant & Bar',
#     'location': {'address': '23 B,Punchkuian Road,Near R K Ashram Metro Station',
#      'crossStreet': 'Opp. Pillar No. 12;Paharganj',
#      'lat': 28.64107541695591,
#      'lng': 77.21269123545952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.64107541695591,
#        'lng': 77.21269123545952}],
#      'distance': 1282,
#      'postalCode': '110055',
#      'cc': 'IN',
#      'city': 'Delhi-NCR',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['23 B,Punchkuian Road,Near R K Ashram Metro Station (Opp. Pillar No. 12;Paharganj)',
#       'Delhi-NCR 110055',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '501cb874e4b0125d26c3583d',
#     'name': 'Sonu Chat House & Restaurant',
#     'location': {'address': '5045, 46, Main Bazar',
#      'crossStreet': 'PAHAR GANJ',
#      'lat': 28.641236076048788,
#      'lng': 77.21317967940327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641236076048788,
#        'lng': 77.21317967940327}],
#      'distance': 1273,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['5045, 46, Main Bazar (PAHAR GANJ)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '537212e7498e0936218174fc',
#     'name': 'Copper Restaurant & Bar',
#     'location': {'address': 'F 37, Central Market, Kirti Nagar',
#      'lat': 28.642375183876393,
#      'lng': 77.21455517162363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.642375183876393,
#        'lng': 77.21455517162363}],
#      'distance': 1326,
#      'postalCode': '110015',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['F 37, Central Market, Kirti Nagar',
#       'New Delhi 110015',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4ddfb10aae60c015c09c17bc',
#     'name': 'The Embassy',
#     'location': {'address': 'Connaught Place',
#      'crossStreet': 'D Block, Inner Circle',
#      'lat': 28.633590069941445,
#      'lng': 77.22122128391564,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.633590069941445,
#        'lng': 77.22122128391564}],
#      'distance': 282,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Connaught Place (D Block, Inner Circle)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '516f8839e4b06f1af7fcc960',
#     'name': 'Satyam Rooftop Restaurant',
#     'location': {'lat': 28.641198,
#      'lng': 77.21369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641198,
#        'lng': 77.21369}],
#      'distance': 1244,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4f8bb468e4b0e6f34a98f43e',
#     'name': 'Grand Sindhi Restaurant',
#     'location': {'lat': 28.640986188196056,
#      'lng': 77.21226454714528,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.640986188196056,
#        'lng': 77.21226454714528}],
#      'distance': 1297,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '5130b836e4b006d9c2177306',
#     'name': 'Lucky Restaurant',
#     'location': {'lat': 28.640972137451172,
#      'lng': 77.21134185791016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.640972137451172,
#        'lng': 77.21134185791016}],
#      'distance': 1349,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4f8be93ee4b01f95a5215d15',
#     'name': 'Naresh Restaurant',
#     'location': {'lat': 28.641097229694818,
#      'lng': 77.2104567190543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.641097229694818,
#        'lng': 77.2104567190543}],
#      'distance': 1414,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '518b4208498ea67bca03278d',
#     'name': 'Kamal Restaurant',
#     'location': {'lat': 28.643332115641723,
#      'lng': 77.22495786591341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.643332115641723,
#        'lng': 77.22495786591341}],
#      'distance': 1422,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4e61e6ef7d8b8540896a76a3',
#     'name': 'Gulnar Restaurant',
#     'location': {'address': 'Hotel Janpath',
#      'crossStreet': 'Janpath',
#      'lat': 28.645266530179676,
#      'lng': 77.21836155239684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.645266530179676,
#        'lng': 77.21836155239684}],
#      'distance': 1551,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Hotel Janpath (Janpath)',
#       'New Delhi',
#       'Delhi',
#       'India']},
#     'categories': [],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '52fa178d498e148cb6fed252',
#     'name': 'Natraj Restaurant',
#     'location': {'lat': 28.642465,
#      'lng': 77.210557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.642465,
#        'lng': 77.210557}],
#      'distance': 1528,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False},
#    {'id': '4d82178cebb4236aebf44b58',
#     'name': 'Al-Sameer Restaurant',
#     'location': {'address': 'Paharganj',
#      'lat': 28.645804284861462,
#      'lng': 77.21470675550181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.645804284861462,
#        'lng': 77.21470675550181}],
#      'distance': 1680,
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'state': 'Delhi',
#      'country': 'India',
#      'formattedAddress': ['Paharganj', 'New Delhi', 'Delhi', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588783620',
#     'hasPerk': False}]}}

# %% [markdown]
# #### We will create a dataframe to store the contents

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id     location.address location.cc location.city  \
# 0  5177f8d5e4b0f361220d4766  35 Community Centre          IN     New Delhi
# 1  5b991352f00a70002cdff3a6                  NaN          IN     New Delhi
# 2  5467166a498e6c2b038ef3bc                  NaN          IN           NaN
# 3  4f5063bbe4b062d9d9d5a175   Hare Krishna hotel          IN     New Delhi
# 4  54086753498e0efae46a1c8f                  NaN          IN           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0            India   New Friends Colony                510
# 1            India                  NaN                 54
# 2            India                  NaN                 77
# 3            India                  NaN               1312
# 4            India                  NaN                 83
#
#                            location.formattedAddress  \
# 0  [35 Community Centre (New Friends Colony), New...
# 1                   [New Delhi 110001, Delhi, India]
# 2                                            [India]
# 3      [Hare Krishna hotel, New Delhi, Delhi, India]
# 4                                            [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 28.63209146656240...     28.632091
# 1  [{'label': 'display', 'lat': 28.631444, 'lng':...     28.631444
# 2  [{'label': 'display', 'lat': 28.63186068637747...     28.631861
# 3  [{'label': 'display', 'lat': 28.641011, 'lng':...     28.641011
# 4  [{'label': 'display', 'lat': 28.6315733133297,...     28.631573
#
#    location.lng location.postalCode location.state  \
# 0     77.224958              110025          Delhi
# 1     77.219244              110001          Delhi
# 2     77.220371                 NaN            NaN
# 3     77.212043                 NaN          Delhi
# 4     77.220624                 NaN            NaN
#
#                          name    referralId
# 0            Anand Restaurant  v-1588783620
# 1       FUJI RESTAURANT & BAR  v-1588783620
# 2         The Host Restaurant  v-1588783620
# 3  Tom Yam Rooftop Restaurant  v-1588783620
# 4         anand restaurant cp  v-1588783620

# %% [markdown]
# #### Let's filter the venues with relevant information and discard the remaining ones

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered.name
# Out:
# 0                            Anand Restaurant
# 1                       FUJI RESTAURANT & BAR
# 2                         The Host Restaurant
# 3                  Tom Yam Rooftop Restaurant
# 4                         anand restaurant cp
# 5                           York's Restaurant
# 6                              KFC Restaurant
# 7                           Zafron restaurant
# 8                              Zen Restaurant
# 9                  My Bar Lounge & Restaurant
# 10                         Kwality Restaurant
# 11                   Japanese Fuji Restaurant
# 12                           Anand Restaurant
# 13                     White water restaurant
# 14            Vega Pure Vegetarian Restaurant
# 15       Parikrama - The Revolving Restaurant
# 16                         Ravayat Restaurant
# 17                 My Lounge Bar & Restaurant
# 18                            Veda Restaurant
# 19                         zaffron Restaurant
# 20                        Maharani Restaurant
# 21                          Gulati Restaurant
# 22           Pioneer - The Chinese Restaurant
# 23                           Royal Restaurant
# 24                         Loknath Restaurant
# 25                           Janta Restaurant
# 26       Oko Pan-Asian Restaurant Lalit Hotel
# 27                             Rajdhani Thali
# 28            Bangla Sweet & Spice restaurant
# 29       Jasmine Restaurant @ The Royal Plaza
# 30                      Metropolis Restaurant
# 31    Novele Restaurant, Shangri La New Delhi
# 32               New Mount Everest Restaurant
# 33             The exotic roof top Restaurant
# 34                           kamal restaurant
# 35                  Singh’s Cafe & Restaurant
# 36                           Leo's Restaurant
# 37                       Malahotra Restaurant
# 38                   My Love Restaurant & Bar
# 39               Sonu Chat House & Restaurant
# 40                    Copper Restaurant & Bar
# 41                                The Embassy
# 42                  Satyam Rooftop Restaurant
# 43                    Grand Sindhi Restaurant
# 44                           Lucky Restaurant
# 45                          Naresh Restaurant
# 46                           Kamal Restaurant
# 47                          Gulnar Restaurant
# 48                          Natraj Restaurant
# 49                       Al-Sameer Restaurant
# Name: name, dtype: object

# %%
restaurant_list = dataframe_filtered[['name', 'lat', 'lng']] # This dataframe will later be used to merge into a larger dataframe containing information about other venues

# %% [markdown]
# #### Let's mark all the restaurants on the map

# %%
restaurants_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(restaurants_map)

# %%
restaurants_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### For Bars

# %% [markdown]
# #### We need to repeat the same process for Bars

# %%
query = 'Bar'
url2 = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,
    query,
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
results2 = requests.get(url2).json()

# %%
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = json_normalize(venues2)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...    False
# 3  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...    False
#
#                          id                            location.address  \
# 0  51470bf7e4b0251c3c4fc8d0                                     F Block
# 1  52b024a1498e919d07553e50                                         NaN
# 2  51690773e4b09433491d990e  81, N-Block, Outer Circle, Connaught Place
# 3  4fae2e04e4b0771d82721cab         G 68, Outer Circle, Connaught Place
# 4  4e89f79e775b4a1123c27d38                           Barakhamba Avenue
#
#   location.cc location.city location.country location.crossStreet  \
# 0          IN         Delhi            India      Inner Circle Cp
# 1          IN           NaN            India                  NaN
# 2          IN     New Delhi            India                  NaN
# 3          IN     New Delhi            India  Opposite Alka Hotel
# 4          IN     New Delhi            India      Connaught Place
#
#    location.distance                          location.formattedAddress  \
# 0                 76   [F Block (Inner Circle Cp), Delhi, Delhi, India]
# 1                209                                            [India]
# 2                240  [81, N-Block, Outer Circle, Connaught Place, N...
# 3                320  [G 68, Outer Circle, Connaught Place (Opposite...
# 4               1037  [Barakhamba Avenue (Connaught Place), New Delh...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 28.63172410105139...     28.631724
# 1  [{'label': 'display', 'lat': 28.63281350472011...     28.632814
# 2  [{'label': 'display', 'lat': 28.63092047361482...     28.630920
# 3  [{'label': 'display', 'lat': 28.63238752868990...     28.632388
# 4  [{'label': 'display', 'lat': 28.62818896975973...     28.628189
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     77.220472                   NaN                 NaN          Delhi
# 1     77.221181                   NaN                 NaN            NaN
# 2     77.222194                   NaN              110001          Delhi
# 3     77.216717                   NaN              110001          Delhi
# 4     77.229767                   NaN              110001          Delhi
#
#                          name    referralId
# 0             Bar King Street  v-1588783642
# 1                      My Bar  v-1588783642
# 2            Cha Bar | चा बार  v-1588783642
# 3  My Bar Lounge & Restaurant  v-1588783642
# 4  24/7 Bar @ The Lalit Hotel  v-1588783642

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered.name
# Out:
# 0                                       Bar King Street
# 1                                                My Bar
# 2                                      Cha Bar | चा बार
# 3                            My Bar Lounge & Restaurant
# 4                            24/7 Bar @ The Lalit Hotel
# 5                                             Banta Bar
# 6                               Henri's bar Le meridien
# 7                                 FUJI RESTAURANT & BAR
# 8                                                My Bar
# 9                                           Station Bar
# 10                                  My Bar Headquarters
# 11                                     BLUES CAFÉ & BAR
# 12                                       cocoa cafe bar
# 13                                Attitude Cafe and Bar
# 14                                     Bar. King Street
# 15                                  Chili's Grill & Bar
# 16                                              Barista
# 17                                       Quote Bar,C.P.
# 18                            Bonsai Bar and Restaurent
# 19                                           Monkey Bar
# 20                                           Bombay Bar
# 21                                            Bunta Bar
# 22                      Surahi - The Veg. Kitchen & Bar
# 23                           My Lounge Bar & Restaurant
# 24                                   office canteen bar
# 25                              The Darzi Bar & Kitchen
# 26                                  Ssky Lounge and Bar
# 27                                           bar shaala
# 28                                      White Heart Bar
# 29                                      Guruvas Inn Bar
# 30                                             Onyx Bar
# 31                                              Gem Bar
# 32                             My Love Restaurant & Bar
# 33                                      Barbeque Nation
# 34                              Copper Restaurant & Bar
# 35                                     Sagar Bar-Be-Que
# 36                                 Bar council of india
# 37                                     Allure resto bar
# 38                                     Sagar Bar-Be-Que
# 39                                      Barista Lavazza
# 40                                  Olive Bar & Kitchen
# 41                                     Bar E Restaurant
# 42                                              Barista
# 43                                          Barush Cafe
# 44    Rabba Maaf Kari (RMK'S) Bar - Best Western Taurus
# 45                       En Üst Kat Cafe Bar ORDU V.I.P
# 46                        Barakhamba Road Metro Station
# 47                                            Barrumbar
# 48                     Barakhamba Indraprakash Building
# 49                   Barista Lavazza (Cottage Emporium)
# Name: name, dtype: object

# %%
bar_list = dataframe_filtered[['name', 'lat', 'lng']] # This dataframe will later be used to merge into a larger dataframe containing information about other venues

# %%
bars_map = folium.Map(location=[latitude, longitude], zoom_start=15) 

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(bars_map)

# %%
bars_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## For Hotels

# %% [markdown]
# #### Finally, we repeat the process for Hotels

# %%
query = 'Hotel'
url3 = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,
    query,
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
results3 = requests.get(url3).json()

# %%
# assign relevant part of JSON to venues
venues3 = results3['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = json_normalize(venues3)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '54135bf5e4b08f3d2429dfde', 'name': 'S...    False
# 1  [{'id': '54135bf5e4b08f3d2429dfde', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id           location.address location.cc  \
# 0  519ba450498eb0c559152d94  P-13/90, Connaught Circus          IN
# 1  4c91f42fae96a0932d79a746                46, Janpath          IN
# 2  4e54ae3ba8093d27cca8aabd                        NaN          IN
# 3  4cd2c5282b52a09380aa2039      G-59 Connaught Circus          IN
# 4  4b80e458f964a520bf9030e3           15 Parliament St          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     New Delhi            India                  NaN                343
# 1     New Delhi            India  Opp. Janpath Market                484
# 2     New Delhi            India                  NaN                429
# 3     New Delhi            India                  NaN                374
# 4     New Delhi            India                  NaN                436
#
#                            location.formattedAddress  \
# 0  [P-13/90, Connaught Circus, New Delhi 110001, ...
# 1  [46, Janpath (Opp. Janpath Market), New Delhi ...
# 2                          [New Delhi, Delhi, India]
# 3  [G-59 Connaught Circus, New Delhi 110001, Delh...
# 4  [15 Parliament St, New Delhi 110 001, Delhi, I...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 28.63231946643500...     28.632319
# 1  [{'label': 'display', 'lat': 28.62704114687105...     28.627041
# 2  [{'label': 'display', 'lat': 28.63471071443335...     28.634711
# 3  [{'label': 'display', 'lat': 28.63389681944778...     28.633897
# 4  [{'label': 'display', 'lat': 28.62873117053961...     28.628731
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     77.216445                   NaN              110001          Delhi
# 1     77.219514                   NaN              110001          Delhi
# 2     77.222016                   NaN                 NaN          Delhi
# 3     77.217241                   NaN              110001          Delhi
# 4     77.216507                   NaN             110 001          Delhi
#
#                         name    referralId venuePage.id
# 0      HOTEL SARAVANA BHAVAN  v-1588783657          NaN
# 1      HOTEL SARAVANA BHAVAN  v-1588783657          NaN
# 2              Kake-Da-Hotel  v-1588783657          NaN
# 3  Radisson Blu Marina Hotel  v-1588783657          NaN
# 4             The Park Hotel  v-1588783657          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered.name
# Out:
# 0                                 HOTEL SARAVANA BHAVAN
# 1                                 HOTEL SARAVANA BHAVAN
# 2                                         Kake-Da-Hotel
# 3                             Radisson Blu Marina Hotel
# 4                                        The Park Hotel
# 5                                       The Lalit Hotel
# 6                              Hotel Metropolitan Delhi
# 7                                    Hotel Ramada Plaza
# 8                              Hotel Aman International
# 9     Hotel The Spot/Tourist Information Center/Trav...
# 10                                        Hotel The Raj
# 11                                The Royal Plaza Hotel
# 12                            Shangri-La's - Eros Hotel
# 13                              Hotel Delhi City Centre
# 14                                        Hotel ShivDev
# 15                                     Star Plaza Hotel
# 16                          hotel alka, connaught place
# 17                                          The Hotel W
# 18                                         Ginger Hotel
# 19                              Hotel Capital New Delhi
# 20                             Hotel Broadway New Delhi
# 21                                         Ajanta Hotel
# 22                          Hotel Surya Plaza-New Delhi
# 23                                 Hotel Palace Heights
# 24                   Hotel Palace Heights, Delhi, India
# 25                                         Hotel Bright
# 26                                           Hotel York
# 27                                           Hotel Alka
# 28                                    Le Meridien Hotel
# 29                             Hotel Claridges Pan Wala
# 30                                           Alka hotel
# 31                               Bright Hotel New Delhi
# 32                        Hotel Kingston Park New Delhi
# 33                            The Corus Hotel New Delhi
# 34                               Marina Hotel New Delhi
# 35                             Hotel C.G. International
# 36                                       Bhape da hotel
# 37                                    Hotel Clark Green
# 38                                      Hotel Blessings
# 39                                      The Royce Hotel
# 40                                        Hotel Janpath
# 41                                 Hans Hotel New Delhi
# 42                        Chambers @ Taj Hotel Mansingh
# 43                                          Hotel Milan
# 44                                   Hotel Gold Regency
# 45                                  The Taj Mahal Hotel
# 46                                  Hotel Star Paradise
# 47                                    Hotel Hari Piorko
# 48                                    Hotel Guruvas Inn
# 49                                        HOTEL GoodDay
# Name: name, dtype: object

# %%
hotel_list = dataframe_filtered[['name', 'lat', 'lng']] # This dataframe will later be used to merge into a larger dataframe containing information about other venues

# %%
hotels_map = folium.Map(location=[latitude, longitude], zoom_start=15) 

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(hotels_map)

# %%
hotels_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Now we will present all the venues on the map together

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14.5)

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) 

# add the hotels as blue circle markers
for lat, lng in zip(hotel_list.lat, hotel_list.lng):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng in zip(bar_list.lat, bar_list.lng):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
    
for lat, lng in zip(restaurant_list.lat, restaurant_list.lng):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # We will group the venues in Cluster

# %% [markdown]
# #### First we will merge the three dataframes for restaurants, bars and hotels

# %%
cluster_list = pd.concat([hotel_list, bar_list, restaurant_list], ignore_index = True)

# %%
cluster_list.head()
# Out:
#                         name        lat        lng  label
# 0      HOTEL SARAVANA BHAVAN  28.632319  77.216445      0
# 1      HOTEL SARAVANA BHAVAN  28.627041  77.219514      0
# 2              Kake-Da-Hotel  28.634711  77.222016      0
# 3  Radisson Blu Marina Hotel  28.633897  77.217241      0
# 4             The Park Hotel  28.628731  77.216507      0

# %% [markdown]
# #### We will perform K-Means clustering to group the data into clusters

# %%
kmeans = KMeans(init="k-means++", n_clusters=3)
kmeans.fit(cluster_list[['lat','lng']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# #### We will store the cluster lables and centres

# %%
labels = kmeans.labels_
centres = kmeans.cluster_centers_

# %% [markdown]
# #### Adding the label column with data in the dataframe

# %%
cluster_list['label'] = labels

# %%
folium.CircleMarker(
        centres[0],
        radius=150,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.3
    ).add_to(venues_map)

# %% [markdown]
# ### We will represent the different clusters with a circle on the map

# %%
folium.CircleMarker(
        centres[1],
        radius=150,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.3
    ).add_to(venues_map)

# %%
folium.CircleMarker(
        centres[2],
        radius=150,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.3
    ).add_to(venues_map)

# %% [markdown]
# ### Next we will mark the centres of the clusters on the map

# %%
folium.Marker(centres[0], popup = 'Cluster 1').add_to(venues_map)
folium.Marker(centres[1], popup = 'Cluster 2').add_to(venues_map)
folium.Marker(centres[2], popup = 'Cluster 3').add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see on the map. Several venues have been grouped into 3 clusters. The circle representing the cluster has not been scaled according to the number of venues in a cluster. Rather they have been made the same size to display the sparsity/density, such that all 3 clusters are visible on the map and the venues can still be differentiated.

# %% [markdown]
# ### Let's check how many venues does each cluster contain

# %%
cluster_list.groupby('label').count()
# Out:
#        name  lat  lng
# label
# 0        84   84   84
# 1        49   49   49
# 2        17   17   17

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# The three clusters have different number of venues.
# Cluster number 1 has 84 venues.
# Cluster number 2 has 49 venues.
# Cluster number 3 has 17 venues.
#
# Since 3rd cluster has only 17 venues and is also much sparse, it would not make much sense to book a hotel room in that area. Number of hotels in that area is also low. There won't be much choice for hotel either.
#
# Cluster 2 and 3, both have lot of venues available. Cluster 2 has a lot of venues right along the center. Cluster 3 has a little less than twice the number of venues than Cluster 3.
#
# Best place to stay would be near the center of Cluster 1 or CLuster 2.
